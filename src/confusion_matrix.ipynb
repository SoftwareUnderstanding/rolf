# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('../final_results.csv', sep=';')
df.set_index(['PipelineID'], inplace=True)

# %%
df_cm = df[['test_tp_mean', 'test_fn_mean', 'test_fp_mean', 'test_tn_mean']]

# %%
df_cm.head(10)
# Out:
#                              test_tp_mean  test_fn_mean  test_fp_mean  \
# PipelineID
# Natural Language Processing          51.0          17.4          24.8
# Natural Language Processing          49.8          18.6          20.8
# Natural Language Processing          48.4          20.0          28.0
# Natural Language Processing          49.6          18.8          24.0
# Natural Language Processing          47.6          20.8          26.8
# Natural Language Processing          41.2          27.2          19.2
# Natural Language Processing          48.6          19.8          17.4
# Natural Language Processing          49.2          19.2          17.2
# Natural Language Processing          58.4          10.0          10.6
# Natural Language Processing          58.8           9.6           4.8
#
#                              test_tn_mean
# PipelineID
# Natural Language Processing          51.4
# Natural Language Processing          55.4
# Natural Language Processing          48.2
# Natural Language Processing          52.2
# Natural Language Processing          49.4
# Natural Language Processing          57.0
# Natural Language Processing          58.8
# Natural Language Processing          59.0
# Natural Language Processing          65.6
# Natural Language Processing          71.4

# %%
for ind, row in df_cm.iterrows():
    print(list(row))
    data = np.asarray(list(row)).reshape(2,2)
    plt.figure(figsize=(5,4))
    sns.heatmap(data, annot=True)
    plt.title('Confusion Matrix '+ind)
    plt.ylabel('Actual Values')
    plt.xlabel('Predicted Values')
    plt.show()
# Out:
# [51.0, 17.4, 24.8, 51.4]
# [49.8, 18.6, 20.8, 55.4]
# [48.4, 20.0, 28.0, 48.2]
# [49.6, 18.8, 24.0, 52.2]
# [47.6, 20.8, 26.8, 49.4]
# [41.2, 27.2, 19.2, 57.0]
# [48.6, 19.8, 17.4, 58.8]
# [49.2, 19.2, 17.2, 59.0]
# [58.4, 10.0, 10.6, 65.6]
# [58.8, 9.6, 4.8, 71.4]
# [94.6, 88.0, 40.6, 311.0]
# [112.2, 70.4, 54.8, 296.8]
# [59.0, 123.6, 26.4, 325.2]
# [104.4, 78.2, 46.0, 305.6]
# [74.2, 108.4, 32.0, 319.6]
# [85.2, 97.4, 36.6, 315.0]
# [115.0, 67.6, 43.4, 308.2]
# [114.8, 67.8, 47.8, 303.8]
# [130.2, 52.4, 10.8, 340.8]
# [152.2, 30.4, 10.0, 341.6]
# [6.6, 6.0, 7.6, 5.4]
# [7.8, 4.8, 8.0, 5.0]
# [5.4, 7.2, 4.0, 9.0]
# [6.4, 6.2, 7.6, 5.4]
# [3.0, 9.6, 3.0, 10.0]
# [9.2, 3.4, 10.0, 3.0]
# [6.4, 6.2, 7.0, 6.0]
# [6.2, 6.4, 7.2, 5.8]
# [8.6, 4.0, 6.4, 6.6]
# [9.4, 3.2, 7.4, 5.6]
# [8.0, 2.0, 1.8, 7.8]
# [9.8, 0.2, 2.2, 7.4]
# [9.4, 0.6, 5.0, 4.6]
# [10.0, 0.0, 3.0, 6.6]
# [7.8, 2.2, 2.8, 6.8]
# [7.8, 2.2, 1.2, 8.4]
# [9.2, 0.8, 0.8, 8.8]
# [9.4, 0.6, 0.8, 8.8]
# [8.4, 1.6, 2.0, 7.6]
# [9.2, 0.8, 1.0, 8.6]
# [20.4, 4.6, 4.4, 20.0]
# [23.6, 1.4, 5.0, 19.4]
# [19.6, 5.4, 8.6, 15.8]
# [22.4, 2.6, 5.8, 18.6]
# [21.6, 3.4, 5.0, 19.4]
# [22.0, 3.0, 3.4, 21.0]
# [22.4, 2.6, 3.4, 21.0]
# [22.4, 2.6, 3.0, 21.4]
# [23.0, 2.0, 3.8, 20.6]
# [22.2, 2.8, 2.2, 22.2]
# [56.2, 8.6, 3.6, 57.6]
# [56.2, 8.6, 1.8, 59.4]
# [47.8, 17.0, 1.2, 60.0]
# [54.4, 10.4, 3.0, 58.2]
# [53.8, 11.0, 8.2, 53.0]
# [55.6, 9.2, 4.4, 56.8]
# [59.2, 5.6, 5.6, 55.6]
# [59.0, 5.8, 5.8, 55.4]
# [60.4, 4.4, 1.4, 59.8]
# [62.6, 2.2, 0.4, 60.8]
