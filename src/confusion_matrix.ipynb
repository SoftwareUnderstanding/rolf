# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('../results/results/results.csv', sep=';')
df.set_index(['PipelineID'], inplace=True)

# %%
df_cm = df[['test_tp_mean', 'test_fn_mean', 'test_fp_mean', 'test_tn_mean']]

# %%
df_cm.head(10)
# Out:
#                              test_tp_mean  test_fn_mean  test_fp_mean  \
# PipelineID
# Sequential                           10.8           3.2           7.8
# Natural Language Processing          52.0          12.0           3.8
# Audio                                 8.0           1.0           1.4
# Computer Vision                     137.6          23.0          10.0
# Graphs                               21.2           0.8           2.4
# Reinforcement Learning               52.6           2.2           0.8
#
#                              test_tn_mean
# PipelineID
# Sequential                            7.2
# Natural Language Processing          65.6
# Audio                                 6.6
# Computer Vision                     303.6
# Graphs                               18.6
# Reinforcement Learning               51.2

# %%
for ind, row in df_cm.iterrows():
    print(list(row))
    data = np.asarray(list(row)).reshape(2,2)
    plt.figure(figsize=(5,4))
    sns.heatmap(data, annot=True)
    plt.title('Confusion Matrix '+ind)
    plt.ylabel('Actual Values')
    plt.xlabel('Predicted Values')
    plt.show()
# Out:
# [10.8, 3.2, 7.8, 7.2]
# [52.0, 12.0, 3.8, 65.6]
# [8.0, 1.0, 1.4, 6.6]
# [137.6, 23.0, 10.0, 303.6]
# [21.2, 0.8, 2.4, 18.6]
# [52.6, 2.2, 0.8, 51.2]
