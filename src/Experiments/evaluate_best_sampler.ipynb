# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/search/sampler_search_sequential.csv', sep=';')
for i in df.columns:
	print(i)
# Out:
# Unnamed: 0
# fit_time
# score_time
# estimator
# test_accuracy
# train_accuracy
# test_f1_macro
# train_f1_macro
# test_f1_weighted
# train_f1_weighted
# test_recall_macro
# train_recall_macro
# test_recall_weighted
# train_recall_weighted
# test_precision_macro
# train_precision_macro
# test_precision_weighted
# train_precision_weighted

# %%
df = df.groupby('estimator').mean()

# %%
df1 = df[['fit_time', 'test_accuracy',
		 'test_precision_macro', 'test_precision_weighted',
		 'test_recall_macro', 'test_recall_weighted',
		 'test_f1_macro', 'test_f1_weighted']]

# %%
df1
# Out:
#                                                     fit_time  test_accuracy  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...  1.928569       0.969549
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...  0.154214       0.532615
#
#                                                     test_precision_macro  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...              0.884713
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...              0.577147
#
#                                                     test_precision_weighted  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...                 0.963312
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...                 0.579652
#
#                                                     test_recall_macro  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...           0.563462
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...           0.537821
#
# ...

# %%
df = pd.read_csv('../../data/search/sampler_search_audio.csv', sep=';')
df = df.groupby('estimator').mean()
df1 = df[['fit_time', 'test_accuracy',
		 'test_precision_macro', 'test_precision_weighted',
		 'test_recall_macro', 'test_recall_weighted',
		 'test_f1_macro', 'test_f1_weighted']]
df1
# Out:
#                                                     fit_time  test_accuracy  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...  1.676406       0.987822
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...  0.107342       0.896842
#
#                                                     test_precision_macro  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...              0.965799
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...              0.905379
#
#                                                     test_precision_weighted  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...                 0.987464
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...                 0.905279
#
#                                                     test_recall_macro  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...           0.792765
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...           0.896667
#
# ...

# %%
df = pd.read_csv('../../data/search/sampler_search_computer_vision.csv', sep=';')
df = df.groupby('estimator').mean()
df1 = df[['fit_time', 'test_accuracy',
		 'test_precision_macro', 'test_precision_weighted',
		 'test_recall_macro', 'test_recall_weighted',
		 'test_f1_macro', 'test_f1_weighted']]
df1
# Out:
#                                                     fit_time  test_accuracy  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...   1.61640       0.973423
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...   2.89839       0.929670
#
#                                                     test_precision_macro  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...              0.486711
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...              0.946070
#
#                                                     test_precision_weighted  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...                 0.947553
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...                 0.938341
#
#                                                     test_recall_macro  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...           0.500000
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...           0.902679
#
# ...

# %%
df = pd.read_csv('../../data/search/sampler_search_natural_language_processing.csv', sep=';')
df = df.groupby('estimator').mean()
df1 = df[['fit_time', 'test_accuracy',
		 'test_precision_macro', 'test_precision_weighted',
		 'test_recall_macro', 'test_recall_weighted',
		 'test_f1_macro', 'test_f1_weighted']]
df1
# Out:
#                                                     fit_time  test_accuracy  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...  1.573845       0.932995
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...  0.706267       0.914052
#
#                                                     test_precision_macro  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...              0.915485
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...              0.930488
#
#                                                     test_precision_weighted  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...                 0.932880
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...                 0.928792
#
#                                                     test_recall_macro  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...           0.880607
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...           0.910731
#
# ...

# %%
df = pd.read_csv('../../data/search/sampler_search_graphs.csv', sep=';')
df = df.groupby('estimator').mean()
df1 = df[['fit_time', 'test_accuracy',
		 'test_precision_macro', 'test_precision_weighted',
		 'test_recall_macro', 'test_recall_weighted',
		 'test_f1_macro', 'test_f1_weighted']]
df1
# Out:
#                                                     fit_time  test_accuracy  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...  1.773157       0.980066
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...  0.309155       0.927102
#
#                                                     test_precision_macro  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...              0.970901
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...              0.933357
#
#                                                     test_precision_weighted  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...                 0.979878
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...                 0.933541
#
#                                                     test_recall_macro  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...           0.867645
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...           0.927333
#
# ...

# %%
df = pd.read_csv('../../data/search/sampler_search_reinforcement_learning.csv', sep=';')
df = df.groupby('estimator').mean()
df1 = df[['fit_time', 'test_accuracy',
		 'test_precision_macro', 'test_precision_weighted',
		 'test_recall_macro', 'test_recall_weighted',
		 'test_f1_macro', 'test_f1_weighted']]
df1
# Out:
#                                                     fit_time  test_accuracy  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...  2.056249       0.976742
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...  0.591598       0.977778
#
#                                                     test_precision_macro  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...              0.973135
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...              0.978331
#
#                                                     test_precision_weighted  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...                 0.976738
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...                 0.978896
#
#                                                     test_recall_macro  \
# estimator
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...           0.947322
# Pipeline(steps=[('vect', TfidfVectorizer(min_df...           0.978337
#
# ...
